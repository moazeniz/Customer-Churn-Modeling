# %%
import numpy as np
import pandas as pd
import lazypredict
from lazypredict.Supervised import LazyClassifier 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('Customer_Churn_Modified.csv')

# %%
# Define feature columns (X) and target column (y)
X = dataset.iloc[:, :-1].values  
y = dataset.iloc[:, -1].values

# Split the dataset into training and testing sets
def custom_train_test_split(X, y, test_size=0.2, stratify=None, random_state=None):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, stratify=stratify, random_state=random_state)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = custom_train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Function to print class proportions
def print_proportions(y):
    unique, counts = np.unique(y, return_counts=True)
    total = len(y)
    for val, count in zip(unique, counts):
        print(f"Class {val}: {count} ({count/total*100:.1f}%)")

print("\nTraining set proportions:")
print_proportions(y_train)
print("\nTest set proportions:")
print_proportions(y_test)
# Out:
# Training set proportions:
# Class 0: 2124 (84.3%)
# Class 1: 396 (15.7%)
#
# Test set proportions:
# Class 0: 531 (84.3%)
# Class 1: 99 (15.7%)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, y_train, y_train)
models_test,predictions_test = clf.fit(X_train, X_test, y_train, y_test)


models_train
# Out:
# 100%|██████████| 31/31 [00:01<00:00, 21.43it/s]
# [LightGBM] [Info] Number of positive: 396, number of negative: 2124
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000577 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1192
# [LightGBM] [Info] Number of data points in the train set: 2520, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.157143 -> initscore=-1.679642
# [LightGBM] [Info] Start training from score -1.679642
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|██████████| 31/31 [00:01<00:00, 28.88it/s]
# [LightGBM] [Info] Number of positive: 396, number of negative: 2124
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1192
# [LightGBM] [Info] Number of data points in the train set: 2520, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.157143 -> initscore=-1.679642
# [LightGBM] [Info] Start training from score -1.679642
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# LabelPropagation                   0.99               0.99     0.99      0.99
# BaggingClassifier                  1.00               0.99     0.99      1.00
# LabelSpreading                     0.99               0.99     0.99      0.99
# KNeighborsClassifier               0.97               0.93     0.93      0.97
# AdaBoostClassifier                 0.95               0.87     0.87      0.95
# NearestCentroid                    0.84               0.87     0.87      0.86
# QuadraticDiscriminantAnalysis      0.82               0.86     0.86      0.84
# PassiveAggressiveClassifier        0.86               0.85     0.85      0.87
# BernoulliNB                        0.84               0.84     0.84      0.86
# GaussianNB                         0.74               0.82     0.82      0.78
# SVC                                0.93               0.78     0.78      0.92
# SGDClassifier                      0.90               0.75     0.75      0.89
# CalibratedClassifierCV             0.90               0.72     0.72      0.88
# LogisticRegression                 0.89               0.71     0.71      0.88
# LinearDiscriminantAnalysis         0.89               0.71     0.71      0.88
# LinearSVC                          0.90               0.71     0.71      0.88
# RidgeClassifier                    0.90               0.70     0.70      0.88
# RidgeClassifierCV                  0.90               0.70     0.70      0.88
# Perceptron                         0.83               0.64     0.64      0.82
# DummyClassifier                    0.84               0.50     0.50      0.77
#
#                                Time Taken
# Model
# LGBMClassifier                       0.07
# XGBClassifier                        0.12
# RandomForestClassifier               0.18
# DecisionTreeClassifier               0.01
# ExtraTreeClassifier                  0.01
# ExtraTreesClassifier                 0.10
# LabelPropagation                     0.22
# BaggingClassifier                    0.06
# LabelSpreading                       0.27
# KNeighborsClassifier                 0.06
# AdaBoostClassifier                   0.09
# NearestCentroid                      0.05
# QuadraticDiscriminantAnalysis        0.01
# PassiveAggressiveClassifier          0.01
# BernoulliNB                          0.01
# GaussianNB                           0.01
# SVC                                  0.08
# SGDClassifier                        0.01
# CalibratedClassifierCV               0.03
# LogisticRegression                   0.02
# LinearDiscriminantAnalysis           0.01
# LinearSVC                            0.01
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.01
# Perceptron                           0.01
# DummyClassifier                      0.00

# %%
models_test
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.98               0.96     0.96      0.98
# XGBClassifier                      0.98               0.96     0.96      0.98
# ExtraTreesClassifier               0.98               0.94     0.94      0.98
# RandomForestClassifier             0.98               0.94     0.94      0.98
# LabelPropagation                   0.97               0.94     0.94      0.97
# LabelSpreading                     0.97               0.94     0.94      0.97
# BaggingClassifier                  0.98               0.94     0.94      0.98
# KNeighborsClassifier               0.97               0.92     0.92      0.96
# DecisionTreeClassifier             0.97               0.92     0.92      0.97
# ExtraTreeClassifier                0.96               0.90     0.90      0.96
# NearestCentroid                    0.83               0.85     0.85      0.85
# PassiveAggressiveClassifier        0.85               0.84     0.84      0.86
# QuadraticDiscriminantAnalysis      0.79               0.84     0.84      0.82
# AdaBoostClassifier                 0.94               0.83     0.83      0.93
# BernoulliNB                        0.84               0.83     0.83      0.85
# GaussianNB                         0.73               0.80     0.80      0.77
# SVC                                0.93               0.77     0.77      0.92
# SGDClassifier                      0.91               0.74     0.74      0.90
# LogisticRegression                 0.90               0.70     0.70      0.88
# CalibratedClassifierCV             0.90               0.70     0.70      0.88
# LinearSVC                          0.90               0.70     0.70      0.88
# LinearDiscriminantAnalysis         0.90               0.69     0.69      0.88
# RidgeClassifier                    0.90               0.69     0.69      0.88
# RidgeClassifierCV                  0.90               0.69     0.69      0.88
# Perceptron                         0.81               0.61     0.61      0.81
# DummyClassifier                    0.84               0.50     0.50      0.77
#
#                                Time Taken
# Model
# LGBMClassifier                       0.05
# XGBClassifier                        0.05
# ExtraTreesClassifier                 0.09
# RandomForestClassifier               0.15
# LabelPropagation                     0.18
# LabelSpreading                       0.20
# BaggingClassifier                    0.05
# KNeighborsClassifier                 0.02
# DecisionTreeClassifier               0.01
# ExtraTreeClassifier                  0.00
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.01
# QuadraticDiscriminantAnalysis        0.01
# AdaBoostClassifier                   0.11
# BernoulliNB                          0.00
# GaussianNB                           0.01
# SVC                                  0.04
# SGDClassifier                        0.01
# LogisticRegression                   0.02
# CalibratedClassifierCV               0.02
# LinearSVC                            0.01
# LinearDiscriminantAnalysis           0.01
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.01
# Perceptron                           0.01
# DummyClassifier                      0.01
